# %%
import glob
import csv
import pandas as pd
import os

path1 = '.\\*2018년.csv'
path2 = '.\\*2019년.csv'
path3 = '.\\*2020년.csv'
merge_path = './merge.csv'
file_list = []
file_list.extend(glob.glob(path1))
file_list.extend(glob.glob(path2))
file_list.extend(glob.glob(path3))

with open(merge_path,'w') as f:
        for i,file in enumerate(file_list):
                if i==0:
                        with open(file,'r') as f2:
                                while True:
                                        line = f2.readline()
                                        if not line:
                                                break
                                        f.write(line)
                else:
                        with open(file,'r') as f2:
                                n = 0
                                while True:
                                        line = f2.readline()
                                        if n != 0:
                                                f.write(line)
                                        if not line:
                                                break
                                        n+=1

# %%
print(merge_path)
df = pd.read_csv(merge_path,encoding='cp949')
# Out:
# ./merge.csv

# %%
df=df.rename(columns={'기준_년_코드': '기준년'})
df=df.rename(columns={'기준_분기_코드': '기준분기코드'})
df=df.rename(columns={'상권_구분_코드': '상권구분코드'})
df=df.rename(columns={'상권_구분_코드명': '상권_구분_코드명'})
df=df.rename(columns={'상권_코드': '상권코드'})
df=df.rename(columns={'상권_코드_명': '상권코드명'})
df=df.rename(columns={'서비스_업종_코드': '서비스업종코드'})
df=df.rename(columns={'서비스_업종_코드_명': '서비스업종코드명'})
df=df.rename(columns={'점포_수': '점포수'})
df=df.rename(columns={'개업_점포_수': '개업점포수'})
df=df.rename(columns={'폐업_점포_수': '폐업점포수'})

# %%
display(df)
# Out:
#           기준년  기준분기코드 상권구분코드 상권_구분_코드명     상권코드         상권_코드_명   서비스업종코드  \
# 0        2018       1      D      발달상권  1001232  서울 종로구 종로3가역_2  CS300040
# 1        2018       1      D      발달상권  1001085      서울 서초구 강남역  CS300041
# 2        2018       1      D      발달상권  1001119          영등포역_2  CS100001
# 3        2018       1      D      발달상권  1001021      가산디지털단지역_1  CS200033
# 4        2018       1      A      골목상권  1000904          도곡로37길  CS300008
# ...       ...     ...    ...       ...      ...             ...       ...
# 1096332  2020       1      A      골목상권  1000001             계동길  CS100005
# 1096333  2020       1      A      골목상권  1000001             계동길  CS100004
# 1096334  2020       1      A      골목상권  1000001             계동길  CS100003
# 1096335  2020       1      A      골목상권  1000001             계동길  CS100002
# 1096336  2020       1      A      골목상권  1000001             계동길  CS100001
#
#          서비스업종코드명  점포수  개업점포수  폐업점포수
# 0        재생용품 판매점    2      0      0
# 1             예술품    7      0      0
# 2           한식음식점  102      4      5
# 3          부동산중개업   34      0      1
# 4           수산물판매    2      0      0
# ...           ...  ...    ...    ...
# 1096332       제과점    2      0      0
# 1096333     양식음식점    3      0      0
# 1096334     일식음식점    3      0      0
# 1096335     중식음식점    0      0      0
# 1096336     한식음식점   19      0      1
#
# [1096337 rows x 11 columns]

# %%
df.to_csv(os.path.join(merge_path), encoding='utf-8', index=False)

# %%
import os
os.getcwd()
# Out:
# 'C:\\Users\\Admin\\mini\\store'

# %%
df = pd.read_csv('./merge.csv',encoding='cp949')
# Out:
# ---------------------------------------------------------------------------
# UnicodeDecodeError                        Traceback (most recent call last)
# <ipython-input-42-d545d846d54b> in <module>
# ----> 1 df = pd.read_csv('./merge.csv',encoding='cp949')
#
# ~\anaconda3\lib\site-packages\pandas\io\parsers.py in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, dialect, error_bad_lines, warn_bad_lines, delim_whitespace, low_memory, memory_map, float_precision)
#     684     )
#     685
# --> 686     return _read(filepath_or_buffer, kwds)
#     687
#     688
#
# ~\anaconda3\lib\site-packages\pandas\io\parsers.py in _read(filepath_or_buffer, kwds)
#     450
#     451     # Create the parser.
# --> 452     parser = TextFileReader(fp_or_buf, **kwds)
#     453
#     454     if chunksize or iterator:
#
# ~\anaconda3\lib\site-packages\pandas\io\parsers.py in __init__(self, f, engine, **kwds)
#     944             self.options["has_index_names"] = kwds["has_index_names"]
#     945
# --> 946         self._make_engine(self.engine)
#     947
#     948     def close(self):
#
# ~\anaconda3\lib\site-packages\pandas\io\parsers.py in _make_engine(self, engine)
#    1176     def _make_engine(self, engine="c"):
#    1177         if engine == "c":
# -> 1178             self._engine = CParserWrapper(self.f, **self.options)
#    1179         else:
#    1180             if engine == "python":
#
# ~\anaconda3\lib\site-packages\pandas\io\parsers.py in __init__(self, src, **kwds)
#    2006         kwds["usecols"] = self.usecols
#    2007
# -> 2008         self._reader = parsers.TextReader(src, **kwds)
#    2009         self.unnamed_cols = self._reader.unnamed_cols
#    2010
#
# pandas\_libs\parsers.pyx in pandas._libs.parsers.TextReader.__cinit__()
#
# pandas\_libs\parsers.pyx in pandas._libs.parsers.TextReader._get_header()
#
# pandas\_libs\parsers.pyx in pandas._libs.parsers.TextReader._tokenize_rows()
#
# pandas\_libs\parsers.pyx in pandas._libs.parsers.raise_parser_error()
#
# UnicodeDecodeError: 'cp949' codec can't decode byte 0xa4 in position 4: illegal multibyte sequence
